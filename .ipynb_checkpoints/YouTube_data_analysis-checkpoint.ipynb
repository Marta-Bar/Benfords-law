# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfYT = pd.read_csv('USvideos.csv')

attr = ['views', 'likes', 
        'dislikes', 'comment_count']

# %% [markdown]
# ### Let's study in more detail the YouTube dataframe

# %%
# missing values?
# only a large amount in the 'description' column has NaN values

dfYT.drop(['description'], axis=1, inplace= True)
dfYT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
# dtypes: bool(3), int64(5), object(7)
# memory usage: 3.9+ MB

# %%
len(dfYT.video_id.unique())   # = 6351, over a total of 40949 videos... why??
# Out:
# 6351

# %%
dfYT.video_id.value_counts().median()
# Out:
# 6.0

# %%
dfYT[dfYT['video_id']=='j4KvrAUjn6c'].head() # are they views/likes/.. per DAY?
# Out:
#           video_id trending_date                                       title  \
# 34550  j4KvrAUjn6c      18.14.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34752  j4KvrAUjn6c      18.15.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34901  j4KvrAUjn6c      18.15.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 34966  j4KvrAUjn6c      18.16.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
# 35180  j4KvrAUjn6c      18.17.05  WE MADE OUR MOM CRY...HER DREAM CAME TRUE!
#
#           channel_title  category_id              publish_time  \
# 34550  Lucas and Marcus           24  2018-05-13T18:03:56.000Z
# 34752  Lucas and Marcus           24  2018-05-13T18:03:56.000Z
# 34901  Lucas and Marcus           24  2018-05-13T18:03:56.000Z
# 34966  Lucas and Marcus           24  2018-05-13T18:03:56.000Z
# 35180  Lucas and Marcus           24  2018-05-13T18:03:56.000Z
#
#                                                     tags    views   likes  \
# 34550  Lucas and Marcus|"Marcus and Lucas"|"Dobre"|"D...  2131702   54280
# 34752  Lucas and Marcus|"Marcus and Lucas"|"Dobre"|"D...  3906727   77378
# 34901  Lucas and Marcus|"Marcus and Lucas"|"Dobre"|"D...  3906727   77378
# 34966  Lucas and Marcus|"Marcus and Lucas"|"Dobre"|"D...  4862649   90451
# 35180  Lucas and Marcus|"Marcus and Lucas"|"Dobre"|"D...  5665445  101461
#
#        dislikes  comment_count  \
# 34550      4696          10705
# 34752     12160          15874
# 34901     12160          15874
# 34966     14792          18035
# 35180     16170          19395
#
#                                        thumbnail_link  comments_disabled  \
# 34550  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg              False
# 34752  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg              False
# 34901  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg              False
# 34966  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg              False
# 35180  https://i.ytimg.com/vi/j4KvrAUjn6c/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 34550             False                   False
# 34752             False                   False
# 34901             False                   False
# 34966             False                   False
# 35180             False                   False
#
#                                              description
# 34550  BEST MOM EVER! TIX ON SALE NOW!! https://www.d...
# 34752  BEST MOM EVER! WANT TO SEE US IN NYC & NJ?!BUY...
# 34901  BEST MOM EVER! WANT TO SEE US IN NYC & NJ?!BUY...
# 34966  BEST MOM EVER! WANT TO SEE US IN NYC & NJ?!BUY...
# 35180  BEST MOM EVER! WANT TO SEE US IN NYC & NJ?!BUY...

# %%
# is trending date always different??

dfYT.loc[34752]==dfYT.loc[34901]  # nope... found one which occurrs two times, same day & same everything!
# Out:
# video_id                  True
# trending_date             True
# title                     True
# channel_title             True
# category_id               True
# publish_time              True
# tags                      True
# views                     True
# likes                     True
# dislikes                  True
# comment_count             True
# thumbnail_link            True
# comments_disabled         True
# ratings_disabled          True
# video_error_or_removed    True
# description               True
# dtype: bool

# %%
dfYT[dfYT.duplicated().values].describe() 
# they have all trending date '18.15.05', but they are not all the ones of that date (48 out of 199)
# Out:
#        category_id         views          likes      dislikes  comment_count
# count    48.000000  4.800000e+01      48.000000     48.000000      48.000000
# mean     21.541667  2.451619e+06   69979.041667   3437.666667    6944.145833
# std       6.506816  3.069923e+06   88460.294824   4994.453708    8162.485797
# min       1.000000  1.584060e+05    1488.000000     79.000000       0.000000
# 25%      22.000000  7.611092e+05   19390.000000    649.750000    1401.250000
# 50%      24.000000  1.566566e+06   36529.500000   1664.500000    4178.000000
# 75%      24.000000  2.589165e+06   79645.000000   3915.000000    8111.750000
# max      28.000000  1.596013e+07  408385.000000  22805.000000   36476.000000

# %% [markdown]
# So, from a preliminary analysis we found out that
# 1. the 'video_id' are NOT unique! usually videos with same id have different trending day, that makes me suppose that views/likes/etc. are PER DAY, and the occurrencies are the number of days the video was in trend. I also found two identical rows, might think of a mistake and erase the duplicates.
# 2. bd

# %%
dfYT.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
# I'm courious about how old are the videos -- I suppose the oldest have more chances to have highest views/likes/etc..

dfYT['publish_time'] = pd.to_datetime(dfYT['publish_time'])
dates = dfYT['publish_time'].copy()
print('Oldest video: ', min(dates))
print('Most recent video: ', max(dates))
# Out:
# Oldest video:  2006-07-23 08:24:11+00:00
# Most recent video:  2018-06-14 01:31:53+00:00

# %%
# how many days later after the publication a video goes in the trends?

# dfYT['trending_date'] = pd.to_datetime(dfYT['trending_date'])
# it looks the dates have a strange format... convert it to timedate accordingly
dfYT['trending_date'] = pd.to_datetime(dfYT['trending_date'], format = '%y.%d.%m')
# don't consider timezone of the published time, as I don't know the one of the trending date
dfYT['publish_time'] = dfYT['publish_time'].apply(lambda x: x.replace(tzinfo=None))
# calculate the delta
diff = dfYT['trending_date']-dfYT['publish_time']

print ('Minimum time: ', diff.min())
print ('Maximum time: ', diff.max())
print ('Mean time: ', diff.mean())
print ('Median time: ', diff.median())
# mean value and mean are quite different.. the most of the videos are viral in very short time!
dfYT['trending_time'] = diff
# Out:
# Minimum time:  -1 days +10:59:56
# Maximum time:  4214 days 15:35:49
# Mean time:  16 days 05:21:53.236220664
# Median time:  4 days 18:59:55

# %%
# erase some useless column

droppable = ['video_id', 
             'tags',
             'thumbnail_link']
dfYT.drop(droppable, axis = 1, inplace= True)

# %%
# erase some useless column

droppable = ['video_id', 
             'tags',
             'thumbnail_link']
dfYT.drop(droppable, axis = 1, inplace= True)

# %% [markdown]
# ### Extract category video with JSON

# %%
import json

category_id_filepath = '../input/youtube-new/US_category_id.json'
category_id_json = open(category_id_filepath)

raw_category_data = json.load(category_id_json)

category_data = {}

for item in raw_category_data['items']:
    category_data[int(item['id'])] = item['snippet']['title']

# Mapping category data into the dataframe

dfYT['category'] = dfYT['category_id'].apply(lambda x: category_data.get(x, 'N/A'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-126-744c6f0e0ced> in <module>
#       2
#       3 category_id_filepath = '../input/youtube-new/US_category_id.json'
# ----> 4 category_id_json = open(category_id_filepath)
#       5
#       6 raw_category_data = json.load(category_id_json)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input/youtube-new/US_category_id.json'

# %% [markdown]
# ### Correlations

# %%
corr_matrix = dfYT.corr()

corr_matrix['comment_count'].sort_values(ascending=False)
# Out:
# comment_count             1.000000
# likes                     0.803057
# dislikes                  0.700184
# views                     0.617621
# video_error_or_removed   -0.003725
# ratings_disabled         -0.013819
# comments_disabled        -0.028277
# category_id              -0.076307
# Name: comment_count, dtype: float64

# %%
num_attr = ['category_id','views', 'likes', 'dislikes', 'comment_count']

sns.heatmap(dfYT[num_attr].corr(),square=True, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data visualization

# %%
from pandas.plotting import scatter_matrix

attributes = ['views', 'likes', 'dislikes', 'comment_count']
scatter_matrix(dfYT[attributes], figsize = (12,8))
plt.show()

# %%
dfYT.groupby(['category_id']).count().plot(kind='bar', legend=False, title = 'number of videos per category_id')
# Out:
# <AxesSubplot:title={'center':'number of videos per category_id'}, xlabel='category_id'>

# %%
dfYT.plot(kind= 'scatter', x ='category_id', y ='comment_count', use_index = dfYT.category_id.unique(), alpha=0.3)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='category_id', ylabel='comment_count'>

# %%
for i in dfYT.category_id.unique():
    print(i)
    print(dfYT[dfYT['category_id']==i]['comment_count'].max(),'\n')
# Out:
# 22
# 383762
#
# 24
# 1361580
#
# 23
# 81051
#
# 28
# 180913
#
# 1
# 108849
#
# 25
# 38936
#
# 17
# 83660
#
# 10
# 1228655
#
# 15
# 44063
#
# 27
# 28835
#
# 26
# 203884
#
# 2
# 10591
#
# 19
# 13631
#
# 20
# 144795
#
# 29
# 658130
#
# 43
# 2181

# %% [markdown]
# ### Benfordness per channel:

# %%
dfYT.channel_title.value_counts()

# there are 2207 different channels
# Out:
# ESPN                                      203
# The Tonight Show Starring Jimmy Fallon    197
# Netflix                                   193
# TheEllenShow                              193
# Vox                                       193
#                                          ...
# Steve Kovach                                1
# Skelly Robot                                1
# David Seymour                               1
# Missguided                                  1
# CHauserable                                 1
# Name: channel_title, Length: 2207, dtype: int64

# %%
# create a dictionary with {'channel title': mean squared error, ....}
RMSE_dict = {}

# lets' consider channels with at least 100 videos
n_videos = 100

for channel in dfYT.channel_title.unique():
    if dfYT.channel_title.value_counts()[channel]< n_videos: continue
    df_ch = dfYT[dfYT['channel_title']==channel]
    c, rmse = Benford(df_ch['views'])
    RMSE_dict[channel] = rmse

# %%
# Channel with higher error:

ch_max = max(RMSE_dict, key=RMSE_dict.get)
ch_max
# Out:
# 'jacksfilms'

# %%
for col in attr:
    print(col.upper())
    Benford_print(dfYT[dfYT['channel_title']==ch_max][col],col)
# Out:
# VIEWS
# RMSE:  0.6659396650507611
#
#
# LIKES
# RMSE:  0.3958628176793254
#
#
# DISLIKES
# RMSE:  0.2350954196617827
#
#
# COMMENT_COUNT
# RMSE:  0.36218149099999236

# %%
# it looks that there are a high number of views starting with 1... maybe this is the reason

# I'll look at the second highest

# would also like to find a treshold for the RMSE to accept

# %%
x = sorted(((v,k) for k,v in RMSE_dict.items()))

ch_sec = x[-2][1]
ch_third = x[-3][1]

# %%
print('Channel name: ', ch_sec)
for col in attr:
    print(col.upper())
    Benford_print(dfYT[dfYT['channel_title']==ch_sec][col],col)
# Out:
# Channel name:  Dude Perfect
# VIEWS
# RMSE:  0.6519436312700669
#
#
# LIKES
# RMSE:  0.5439339214383625
#
#
# DISLIKES
# RMSE:  0.33032287697206075
#
#
# COMMENT_COUNT
# RMSE:  0.5482661242510543

# %%
print('Cannel name: ', ch_third)

for col in attr:
    print(col.upper())
    Benford_print(dfYT[dfYT['channel_title']==ch_third][col],col)
# Out:
# Cannel name:  Smosh
# VIEWS
# RMSE:  0.5859910080056233
#
#
# LIKES
# RMSE:  0.5820150755111723
#
#
# DISLIKES
# RMSE:  0.26952260575861064
#
#
# COMMENT_COUNT
# RMSE:  0.4328506344767021

# %% [markdown]
# ### Benfordness per category

# %%
dfYT.category_id.value_counts()
# Out:
# 24    9964
# 10    6472
# 26    4146
# 23    3457
# 22    3210
# 25    2487
# 28    2401
# 1     2345
# 17    2174
# 27    1656
# 15     920
# 20     817
# 19     402
# 2      384
# 43      57
# 29      57
# Name: category_id, dtype: int64

# %%
# create a dictionary with {'category': mean squared error, ....}
RMSE_dict_cat = {}

for cat in dfYT.category_id.unique():
    df_cat = dfYT[dfYT['category_id']==cat]
    c, rmse = Benford(df_cat['views'])
    RMSE_dict_cat[cat] = rmse
RMSE_dict_cat
# Out:
# {22: 0.04651471505684041,
#  24: 0.025905928776964602,
#  23: 0.09134464065246624,
#  28: 0.05111409653175282,
#  1: 0.058399739886736884,
#  25: 0.0341634450406261,
#  17: 0.04154766620408565,
#  10: 0.023954184645745873,
#  15: 0.09715325914590918,
#  27: 0.13874719128893698,
#  26: 0.06305245709526837,
#  2: 0.09935250412470371,
#  19: 0.10628170023652969,
#  20: 0.06598509689068549,
#  29: 0.2786996533307347,
#  43: 0.7734845510876377}

# %%
# Channel with higher error:

cat_max = max(RMSE_dict_cat, key=RMSE_dict_cat.get)
cat_max  # 43 -- Shows

dict(sorted(RMSE_dict_cat.items(), key=lambda item: item[1]))
# Out:
# {10: 0.023954184645745873,
#  24: 0.025905928776964602,
#  25: 0.0341634450406261,
#  17: 0.04154766620408565,
#  22: 0.04651471505684041,
#  28: 0.05111409653175282,
#  1: 0.058399739886736884,
#  26: 0.06305245709526837,
#  20: 0.06598509689068549,
#  23: 0.09134464065246624,
#  15: 0.09715325914590918,
#  2: 0.09935250412470371,
#  19: 0.10628170023652969,
#  27: 0.13874719128893698,
#  29: 0.2786996533307347,
#  43: 0.7734845510876377}
